# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics

# %%
# importing yolo model
from ultralytics import YOLO

# %%
# initializing the model
model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 153MB/s]

# %%
DATA_CFG = '/content/drive/MyDrive/OCR/data/dataset.yaml'

# %%
# training the model
results = model.train(
    data = DATA_CFG,
    batch = 24,
    epochs = 35,
    device = 0,
    lr0 = 3e-4,
    patience = 0,
    optimizer = 'AdamW',
    verbose = True,
    imgsz = 640,
    save_period = 10
    )
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Save Model

# %%
import os
from shutil import copy2

# %%
src_path = "/content/runs/detect/train/weights/best.pt"
dst_path = "/content/drive/MyDrive/OCR/model/best.pt"

# %%
copy2(src_path, dst_path)
# Out:
# '/content/drive/MyDrive/OCR/model/best.pt'

# %% [markdown]
# ## Save Logs

# %%
dst_dir = "/content/drive/MyDrive/OCR/logs"
src_dir = "/content/runs/detect/train"

log_files = [file_name for file_name in os.listdir(src_dir) if file_name != "weights"]

# %%
for file_name in log_files:
    src_path = os.path.join(src_dir, file_name)
    dst_path = os.path.join(dst_dir, file_name)

    copy2(src_path, dst_path)
